# %%
import textwrap
from langchain_teddynote.document_loaders import HWPLoader

# %%
# HWP Loader 객체 생성
hwp_loader = HWPLoader("./documents/국가정보보안기본지침(23.1.31).hwp")

# %%
# 문서 로드
docs = hwp_loader.load()

# %%
print(docs)
# Out:
# [Document(metadata={'source': './documents/국가정보보안기본지침(23.1.31).hwp'}, page_content='국가정보원 지침cccccccc국가 정보보안 기본지침2023. 1. 31목   차제1장 총 칙ȃ1   제1조(목적)ȃ1   제2조(정의)ȃ1   제3조(적용범위)ȃ11   제4조(책무)ȃ11   제5조(정보보안담당관 운영)ȃ11   제6조(연도 추진계획 수립)ȃ13   제7조(정보보안내규)ȃ13   제8조(정보보안감사 등)ȃ13   제9조(정보보안교육)ȃ15   제10조(사이버보안진단의 날)ȃ15제2장 정보화사업 보안ȃ16 제1절 사업 계획ȃ16   제11조(보안책임)ȃ16   제12조(보안대책 수립)ȃ16   제13조(제안요청서 기재사항)ȃ17 제2절 보안성 검토ȃ18   제14조(검토 시기 및 절차)ȃ18   제15조(검토 기관)ȃ19   제16조(검토 생략)ȃ21   제17조(제출 문서)ȃ22   제18조(검토결과 조치)ȃ23   제19조(현황 제출)ȃ23 제3절 제품 도입ȃ23   제19조의2(보안기능 시험)ȃ23   제20조(정보통신제품 도입)ȃ24   제21조(안전성 검증필 제품 목록)ȃ24   제22조(검증필 암호모듈 목록 및 운용관리)㽈ȃ27   제23조(영상정보처리기기 도입)ȃ28   제24조(도입현황 제출)ȃ28   제24조의2(상용소프트웨어 도입)ȃ28 제4절 계약 및 사업 수행ȃ28   제25조(계약 특수조건)ȃ29   제26조(용역업체 보안)ȃ29   제27조(소프트웨어 개발보안)ȃ31   제27조의2(발주기관내 작업장소 보안)䱬ȃ31   제28조(원격지 개발보안)ȃ32   제28조의2(원격지에서의 온라인 개발)䱬ȃ33   제29조(소프트웨어 산출물 제공)ȃ33   제30조(누출금지정보 유출시 조치)ȃ34 제5절 보안적합성 검증ȃ35   제31조(대상 제품)ȃ35   제32조(검증기관 및 신청)ȃ35   제33조(검증 신청시 제출물)ȃ35   제34조(안전성 시험)ȃ36   제35조(검증
# ...

# %%
print(docs[0].metadata)
# Out:
# {'source': './documents/국가정보보안기본지침(23.1.31).hwp'}

# %%
print(docs[0].page_content[:1000])
# Out:
# 국가정보원 지침cccccccc국가 정보보안 기본지침2023. 1. 31목   차제1장 총 칙ȃ1   제1조(목적)ȃ1   제2조(정의)ȃ1   제3조(적용범위)ȃ11   제4조(책무)ȃ11   제5조(정보보안담당관 운영)ȃ11   제6조(연도 추진계획 수립)ȃ13   제7조(정보보안내규)ȃ13   제8조(정보보안감사 등)ȃ13   제9조(정보보안교육)ȃ15   제10조(사이버보안진단의 날)ȃ15제2장 정보화사업 보안ȃ16 제1절 사업 계획ȃ16   제11조(보안책임)ȃ16   제12조(보안대책 수립)ȃ16   제13조(제안요청서 기재사항)ȃ17 제2절 보안성 검토ȃ18   제14조(검토 시기 및 절차)ȃ18   제15조(검토 기관)ȃ19   제16조(검토 생략)ȃ21   제17조(제출 문서)ȃ22   제18조(검토결과 조치)ȃ23   제19조(현황 제출)ȃ23 제3절 제품 도입ȃ23   제19조의2(보안기능 시험)ȃ23   제20조(정보통신제품 도입)ȃ24   제21조(안전성 검증필 제품 목록)ȃ24   제22조(검증필 암호모듈 목록 및 운용관리)㽈ȃ27   제23조(영상정보처리기기 도입)ȃ28   제24조(도입현황 제출)ȃ28   제24조의2(상용소프트웨어 도입)ȃ28 제4절 계약 및 사업 수행ȃ28   제25조(계약 특수조건)ȃ29   제26조(용역업체 보안)ȃ29   제27조(소프트웨어 개발보안)ȃ31   제27조의2(발주기관내 작업장소 보안)䱬ȃ31   제28조(원격지 개발보안)ȃ32   제28조의2(원격지에서의 온라인 개발)䱬ȃ33   제29조(소프트웨어 산출물 제공)ȃ33   제30조(누출금지정보 유출시 조치)ȃ34 제5절 보안적합성 검증ȃ35   제31조(대상 제품)ȃ35   제32조(검증기관 및 신청)ȃ35   제33조(검증 신청시 제출물)ȃ35   제34조(안전성 시험)ȃ36   제35조(검증결과 통보 및 조치)ȃ36   제36조(취약점 조치)ȃ36   제37조(형상변경 및 용도변경시 조치)䳴ȃ37   제39조(이행여부 확인)ȃ37제3장 정
# ...

# %%
len(docs)
# 문서 자체가 1개 통으로.
# PDF같은 경우는 페이지마다
# Out:
# 1
